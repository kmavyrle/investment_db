# %%
import yfinance as yf

import pandas as pd
import numpy as np

import statsmodels.api as sm
from scipy.stats import norm
from sklearn.feature_selection import RFE
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import featEngine as fe

import datetime

# %load_ext autoreload
# %autoreload 2

# %%
# Manual Calculation for Beta

def get_beta_pvals(betas,X,Y):
    #betas.index = X.columns
    betas = pd.DataFrame(betas,index = X.columns,columns = Y.columns)
    #print(betas)
    preds = X@betas
    #print(preds)
    e = df - preds
    #print(e)
    n,p = X.shape#X@betas
    dof = n - p
    resid_var = ((e.T@e)/dof).values[0]
    #resid_var.values[0]

    #resid_var = resid_var[0][0]
    # Step 5: Standard errors of coefficients
    cov_matrix = resid_var * np.linalg.inv(X.T @ X)
    std_errors = np.sqrt(np.diag(cov_matrix))
    z_stats = betas.values.T/std_errors

    p_values = [2 * (1 - norm.cdf(abs(z))) for z in z_stats]
    return p_values

# %% [markdown]
# # Get Features

# %%
tkr = 'UEC'
fdmnt = pd.read_excel("Financial Data.xlsx",sheet_name = tkr)
fdmnt.set_index('Date',inplace = True)
fdmnt.index = [datetime.datetime.strptime(dt,"%Y-%m-%d") + datetime.timedelta(days = 48) for dt in fdmnt.index]
tkr_exch = 'UEC'
fdmnt.drop([tkr_exch,'Quarter','market_cap'],axis = 1,inplace = True)

# %% [markdown]
# ## Get dependent variable

# %%
df = yf.download(tkr_exch)[['Close']]       ## Get Financial Data
fwd = 20*2
df = df.pct_change(fwd).shift(-fwd)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fcln = fe.featureClean(fdmnt,df)
df = fcln.custom_reindex(df,fdmnt)     ## Reindex with the financial data with the fundamental data
df = df.fillna(0)
df
# Out:
#             (Close, UEC)
# 2006-02-17      0.000000
# 2006-05-18      0.000000
# 2006-08-17      0.000000
# 2006-11-17      0.000000
# 2007-02-17      0.000000
# ...                  ...
# 2024-03-19      0.092332
# 2024-06-17     -0.219472
# 2024-09-17      0.542169
# 2024-12-18     -0.163408
# 2025-03-20     -0.058719
#
# [77 rows x 1 columns]

# %%
lvls = fdmnt.columns
chg = fdmnt.columns
X = fcln.generate_features(chg,lvls)
X = fcln.clean_features(X)
X
# Out:
#              eps_lvl  cf_net_inc_lvl  ebitda_lvl  cash_flow_per_sh_lvl  \
# 2006-02-17  0.532628        1.444665    1.643065              1.231608
# 2006-05-18  0.310308        1.333608    1.514405              0.975524
# 2006-08-17 -0.992556        0.775421    0.866544              0.261423
# 2006-11-17 -1.567203        0.497848    0.486170             -0.883858
# 2007-02-17 -2.277750        0.206905    0.144943             -1.548646
# ...              ...             ...         ...                   ...
# 2024-03-19  1.155418        1.139709   -0.364759              0.085050
# 2024-06-17  1.041340        0.358789   -1.441711              0.060548
# 2024-09-17  0.833915       -1.041619   -3.821379             -0.835261
# 2024-12-18  0.539560       -3.145007   -4.037599             -0.055410
# 2025-03-20  0.397839       -4.263398   -3.117107              0.534178
#
#             ebitda_per_sh_lvl  cash_flow_to_net_inc_lvl  bs_sh_out_lvl  \
# 2006-02-17           0.598642                 -0.189282      -0.996584
# 2006-05-18           0.295962                 -0.162417      -1.058142
# 2006-08-17          -1.170544                 -0.161824      -1.049820
# 2006-02-17                      0.000000       0.000000       0.000000
# 2006-05-18                      1.774491       4.711889       0.014524
# 2006-08-17                     -6.717061       6.997960       3.498135
# 2006-11-17                      0.589903      -0.243331      -1.536124
# 2007-02-17                     -0.426638      -0.057244       1.674290
# ...                                  ...            ...            ...
# 2024-03-19                     -0.084705      -0.072007       0.476184
# 2024-06-17                      0.005806      -0.108367       0.557911
# 2024-09-17                      0.024959      -0.203596      -0.420075
# 2024-12-18                     -0.364379      -0.059972       1.774942
# 2025-03-20                      0.551825      -0.172746      -1.610556
#
# [77 rows x 151 columns]

# %%
fsel = fe.featureSelect(X,df)
features = fsel.feature_selection_mk1()
features
# Out:
# ['cf_change_in_accounts_payable_lvl',
#  'cf_other_investing_act_detailed_lvl',
#  'cf_net_chng_cash_lvl',
#  'is_other_operating_expenses_lvl',
#  'is_nonop_income_loss_lvl',
#  'net_debt_to_shrhldr_eqty_lvl',
#  'cur_ratio_lvl',
#  'cf_change_in_prepaid_assets_chg',
#  'cf_proc_fr_repurch_eqty_detailed_chg',
#  'cf_incr_cap_stock_chg',
#  'cf_net_chng_cash_chg',
#  'pr_to_free_cash_flow_chg',
#  'is_operating_expn_chg',
#  'is_other_operating_expenses_chg',
#  'is_nonop_income_loss_chg',
#  'is_other_nonop_income_loss_chg',
#  'is_net_income_chg',
#  'is_earn_for_common_chg',
#  'dil_eps_cont_ops_chg',
#  'bs_accum_depr_chg']

# %% [markdown]
# # Now Get all Relevant Information for All Tickers

# %%
tickers_map = pd.read_excel('tickers_map.xlsx')
filepath = "Financial Data.xlsx"
sheet_names = pd.ExcelFile(filepath).sheet_names

# %%
features_map = {}
for tkr in sheet_names:
    try:
        fdmnt = pd.read_excel("Financial Data.xlsx",sheet_name = tkr)
        tkr_exch = tickers_map[tickers_map['Name']==tkr]['Ticker'].values[0]
        fdmnt.set_index('Date',inplace = True)
        fdmnt.index = [datetime.datetime.strptime(dt,"%Y-%m-%d") + datetime.timedelta(days = 48) for dt in fdmnt.index]
        fdmnt.drop([tkr_exch,'Quarter','market_cap'],axis = 1,inplace = True)

        df = yf.download(tkr_exch)[['Close']]       ## Get Financial Data
        fwd = 20
        df = df.pct_change(fwd).shift(-fwd)

        fcln = fe.featureClean(fdmnt,df)
        df = fcln.custom_reindex(df,fdmnt)     ## Reindex with the financial data with the fundamental data
        df = df.fillna(0)

        lvls = fdmnt.columns
        chg = fdmnt.columns
        X = fcln.generate_features(chg,lvls)
        X = fcln.clean_features(X)

        fsel = fe.featureSelect(X,df)
        features = fsel.feature_selection_mk1()
        features_map[tkr] = pd.DataFrame(features,columns = ['Features'])
    except:
        print(tkr," failed")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CGN Mining  failed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Haidilao  failed
# [*********************100%***********************]  1 of 1 completed

# %%
with pd.ExcelWriter("features_map.xlsx", engine="xlsxwriter") as writer:
    for sheet_name, dataframe in features_map.items():
        dataframe.to_excel(writer, sheet_name=sheet_name, index=False)

# %% [markdown]
# # ElasticNet Attempt

# %%
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression

enet = ElasticNet(alpha=0.1, l1_ratio=0, random_state=42,max_iter = 10000)
enet.fit(X,df)

lr = LinearRegression().fit(X,df)
# Out:
# c:\Users\kmavy\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1
# 2019-08-17       0.033058 -0.077638
# 2019-11-17       0.074806 -0.051639
# 2020-02-17      -0.227605 -0.091424
# 2020-05-18       0.168746  0.009924
# 2020-08-17       0.043688  0.014371
# 2020-11-17       0.575025  0.472009
# 2021-02-17      -0.241692 -0.218401
# 2021-05-18       0.102810  0.050485
# 2021-08-17       0.124816  0.030988
# 2021-11-17      -0.381957 -0.394729
# 2022-02-17      -0.246032 -0.286770
# 2022-05-18       0.244819  0.187339
# 2022-08-17      -0.237836 -0.236986
# 2022-11-17       0.457251  0.340258
# 2023-02-17       0.071655  0.012594
# 2023-05-18      -0.042740 -0.045020
# 2023-08-17      -0.100977 -0.165036
# 2023-11-17      -0.184417 -0.206465
# 2024-02-17       0.142857  0.075927
# 2024-05-18      -0.058718 -0.145293
# 2024-08-17       0.059971  0.049170
# 2024-11-17       0.049727  0.040541
# 2025-02-17       0.013188 -0.051419
# 2025-05-18       0.117274  0.048669

# %%
def get_summary_stats(betas,X,Y):
    pvals = get_beta_pvals(enet.coef_,X,Y)[0]
    df= pd.DataFrame(zip(betas,pvals))
    df.index = X.columns
    df.columns = ['betas','p-value']
    return df

# %%
get_summary_stats(enet.coef_,X,df)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 get_summary_stats(enet.coef_,X,df)
#
# Cell In[24], line 2, in get_summary_stats(betas, X, Y)
#       1 def get_summary_stats(betas,X,Y):
# ----> 2     pvals = get_beta_pvals(enet.coef_,X,Y)[0]
#       3     df= pd.DataFrame(zip(betas,pvals))
#       4     df.index = X.columns
#
# Cell In[2], line 18, in get_beta_pvals(betas, X, Y)
#      13 resid_var = ((e.T@e)/dof).values[0]
#      14 #resid_var.values[0]
#      15
#      16 #resid_var = resid_var[0][0]
#      17 # Step 5: Standard errors of coefficients
# ---> 18 cov_matrix = resid_var * np.linalg.inv(X.T @ X)
#      19 std_errors = np.sqrt(np.diag(cov_matrix))
#      20 z_stats = betas.values.T/std_errors
#
# File ~\AppData\Roaming\Python\Python310\site-packages\numpy\linalg\linalg.py:561, in inv(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562 return wrap(ainv.astype(result_t, copy=False))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\numpy\linalg\linalg.py:112, in _raise_linalgerror_singular(err, flag)
#     111 def _raise_linalgerror_singular(err, flag):
# --> 112     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
pred = enet.coef_.T@X.T
df['pred'] = pred
df.plot()
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#               (Close, UEC)      pred
# (Close, UEC)      1.000000  0.575267
# pred              0.575267  1.000000

# %% [markdown]
# ## Feature Selection

# %%
fdmt
# Out:
#             pe_ratio_lvl   eps_lvl  revenue_per_sh_lvl  profit_margin_lvl  \
# 2006-02-17           NaN -0.131960            0.000097      -1.354794e+05
# 2006-05-18           NaN -0.174538            0.000060      -2.907074e+05
# 2006-08-17           NaN -0.424056            0.000030      -1.393653e+06
# 2006-11-17           NaN -0.534110                 NaN                NaN
# 2007-02-17           NaN -0.670191                 NaN                NaN
# ...                  ...       ...                 ...                ...
# 2024-03-19    877.803076 -0.012686            0.154639      -8.203401e+00
# 2024-06-17    444.967298 -0.034533            0.099549      -3.468971e+01
# 2024-09-17    444.967298 -0.074259            0.000569      -1.304509e+04
# 2024-12-18           NaN -0.130632            0.042643      -3.063419e+02
# 2025-03-20           NaN -0.157774            0.161775      -9.752682e+01
#
#             return_com_eqy_lvl  is_gross_profit_lvl  cf_net_inc_lvl  \
# 2006-02-17                 NaN              -1460.0        -1467947
# 2006-05-18                 NaN              -1460.0        -2707612
# 2006-08-17                 NaN              -1460.0        -8938361
# 2006-11-17                 NaN              -1460.0       -12036756
# 2007-02-17                 NaN                  NaN       -15284393
# ...                        ...                  ...             ...
# 2024-03-19                 NaN           21279000.0        -4872000
# 2024-06-17                 NaN           15060000.0       -13589000
# 2024-09-17                 NaN              37000.0       -29221000
# 2024-12-18                 NaN            6270000.0       -52700000
# 2025-03-20                 NaN           24477000.0       -65184000
#
#             ebitda_lvl  cash_flow_per_sh_lvl  ebitda_per_sh_lvl  ...  \
# 2006-02-17    -1701953             -0.027804          -0.113544  ...
# 2006-05-18    -2942019             -0.057888          -0.166795  ...
# 2006-08-17    -9186310             -0.141778          -0.424800  ...
# 2006-11-17   -12852475             -0.276322          -0.538538  ...
# 2007-02-17   -16141325             -0.354419          -0.676346  ...
# ...                ...                   ...                ...  ...
# 2024-03-19   -21054000             -0.162498          -0.054820  ...
# 2024-06-17   -31434000             -0.165376          -0.079882  ...
# 2024-09-17   -54370000             -0.270613          -0.138169  ...
# 2024-12-18   -56454000             -0.178998          -0.139938  ...
# 2025-03-20   -47582000             -0.109736          -0.115169  ...
#
#             bs_total_equity_chg  bs_tot_liab_and_eqy_chg  bs_sh_out.1_chg  \
# 2006-02-17                  NaN                      NaN              NaN
# 2006-05-18             116087.0                  16232.0       -7101169.0
# 2006-08-17            4024338.0                3962686.0         960000.0
# 2006-11-17           -1116486.0               -1094203.0        1165000.0
# 2007-02-17           10857541.0               11205520.0        6260000.0
# ...                         ...                      ...              ...
# 2024-03-19           86945000.0               80749000.0       11390248.0
# 2024-06-17            9490000.0                -610000.0        4892141.0
# 2024-09-17            -527000.0               11560000.0        4404654.0
# 2024-12-18           45905000.0               27970000.0        8786660.0
# 2025-03-20           53195000.0               64159000.0        9269837.0
#
#             bs_total_capital_leases_chg  net_debt_chg  \
# 2006-02-17                          NaN           NaN
# 2006-05-18                          NaN        4295.0
# 2006-08-17                          NaN    -3934816.0
# 2006-11-17                          NaN     1633937.0
# 2007-02-17                          NaN   -11177633.0
# ...                                 ...           ...
# 2024-03-19                          NaN   -32047000.0
# 2024-06-17                          NaN    -5439000.0
# 2024-09-17                          NaN      193000.0
# 2024-12-18                          NaN  -103063000.0
# 2025-03-20                          NaN   129083000.0
#
#             net_debt_to_shrhldr_eqty_chg  tce_ratio_chg  cur_ratio_chg  \
# 2006-02-17                           NaN            NaN            NaN
# 2006-05-18                     53.481464     120.208384       0.221201
# 2006-08-17                   -206.013529     176.677549      24.542106
# 2006-11-17                     17.281382      -2.192480     -10.604673
# 2007-02-17                    -13.783273       2.404122      11.808895
# ...                                  ...            ...            ...
# 2024-03-19                     -3.334078       2.039460       3.444294
# 2024-06-17                     -0.568134       1.141319       4.014872
# 2024-09-17                      0.017173      -1.210983      -2.812956
# 2024-12-18                    -11.880683       2.336739      12.511600
# 2025-03-20                     16.117755      -0.448928     -11.124323
#
#             cash_conversion_cycle_chg  num_of_employees_chg
# 2006-02-17                        NaN                   NaN
# 2006-05-18                        NaN                   NaN
# 2006-08-17                        NaN                   NaN
# 2006-11-17                        NaN                   NaN
# 2007-02-17                        NaN                   NaN
# ...                               ...                   ...
# 2024-03-19                 255.830284                   NaN
# 2024-06-17                 278.947310                   NaN
# 2024-09-17               79357.813168                   NaN
# 2024-12-18              -78328.995734                   NaN
# 2025-03-20               -1137.326698                   NaN
#
# [77 rows x 392 columns]

# %%
lvl = fdmnt.columns
chg = fdmnt.columns
fdmt = clean_features(fdmnt,chg,lvl,standardize=False)
feats = enhanced_feature_selector(fdmt,df,model_type = 'ridge')

# %%
pd.concat([fdmt[feats],df],axis = 1).corr()
# Out:
#                                            cf_purchase_of_fixed_prod_assets_lvl  \
# cf_purchase_of_fixed_prod_assets_lvl                                   1.000000
# cash_flow_to_net_inc.1_lvl                                            -0.027510
# cur_ratio_lvl                                                         -0.089525
# cf_proc_fr_repurch_eqty_detailed_chg                                  -0.026441
# cf_cap_expenditures_chg                                                0.290332
# free_cash_flow_per_sh_chg                                              0.114238
# pr_to_free_cash_flow_chg                                              -0.007700
# cash_flow_to_net_inc.1_chg                                            -0.033786
# is_operating_expn_chg                                                  0.013283
# is_other_operating_expenses_chg                                        0.148730
# is_oper_income_chg                                                     0.137413
# is_nonop_income_loss_chg                                              -0.198876
# is_ni_including_minority_int_ratio_chg                                 0.148487
# is_sh_for_diluted_eps_chg                                              0.062312
# bs_c_and_ce_and_sti_detailed_chg                                       0.027570
# bs_other_current_assets_detailed_chg                                   0.007508
# bs_accum_depr_chg                                                     -0.217791
# bs_acct_payable_and_accruals_detailed_chg                             -0.039902
# bs_cur_liab_chg                                                        0.013318
# cur_ratio_chg                                                          0.056319
# (Close, UEC)                                                           0.165096
#
#                                            cash_flow_to_net_inc.1_lvl  \
# cf_purchase_of_fixed_prod_assets_lvl                        -0.027510
# cash_flow_to_net_inc.1_lvl                                   1.000000
# cur_ratio_lvl                                                0.100547
# cf_proc_fr_repurch_eqty_detailed_chg                         0.011224
# cf_cap_expenditures_chg                                     -0.001027
# free_cash_flow_per_sh_chg                                   -0.110513
# pr_to_free_cash_flow_chg                                     0.148775
# cash_flow_to_net_inc.1_chg                                   0.792720
# is_operating_expn_chg                                        0.020807
# is_other_operating_expenses_chg                              0.030846
# is_oper_income_chg                                          -0.295983
# is_nonop_income_loss_chg                                    -0.119277
# is_ni_including_minority_int_ratio_chg                      -0.100861
# is_sh_for_diluted_eps_chg                                    0.401535
# bs_c_and_ce_and_sti_detailed_chg                            -0.044781
# bs_other_current_assets_detailed_chg                        -0.362538
# bs_accum_depr_chg                                           -0.000664
# bs_acct_payable_and_accruals_detailed_chg                   -0.229581
# bs_cur_liab_chg                                             -0.207259
# cur_ratio_chg                                                0.126610
# (Close, UEC)                                                 0.040760
#
#                                            cur_ratio_lvl  \
# cf_purchase_of_fixed_prod_assets_lvl           -0.089525
# cash_flow_to_net_inc.1_lvl                      0.100547
# cur_ratio_lvl                                   1.000000
# cf_proc_fr_repurch_eqty_detailed_chg            0.081451
# cf_cap_expenditures_chg                         0.045730
# free_cash_flow_per_sh_chg                      -0.069654
# pr_to_free_cash_flow_chg                        0.025419
# cash_flow_to_net_inc.1_chg                     -0.007846
# is_operating_expn_chg                           0.255466
# is_other_operating_expenses_chg                 0.106589
# is_oper_income_chg                             -0.122099
# is_nonop_income_loss_chg                       -0.088110
# is_ni_including_minority_int_ratio_chg         -0.122602
# is_sh_for_diluted_eps_chg                       0.030149
# bs_c_and_ce_and_sti_detailed_chg                0.042514
# bs_other_current_assets_detailed_chg            0.000504
# bs_accum_depr_chg                              -0.168532
# bs_acct_payable_and_accruals_detailed_chg      -0.101035
# bs_cur_liab_chg                                -0.277044
# cur_ratio_chg                                   0.456486
# (Close, UEC)                                   -0.114813
#
#                                            cf_proc_fr_repurch_eqty_detailed_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                                  -0.026441
# cash_flow_to_net_inc.1_lvl                                             0.011224
# cur_ratio_lvl                                                          0.081451
# cf_proc_fr_repurch_eqty_detailed_chg                                   1.000000
# cf_cap_expenditures_chg                                               -0.086086
# free_cash_flow_per_sh_chg                                             -0.510161
# pr_to_free_cash_flow_chg                                              -0.001518
# cash_flow_to_net_inc.1_chg                                             0.005005
# is_operating_expn_chg                                                 -0.040818
# is_other_operating_expenses_chg                                       -0.066715
# is_oper_income_chg                                                    -0.414994
# is_nonop_income_loss_chg                                              -0.118295
# is_ni_including_minority_int_ratio_chg                                -0.228474
# is_sh_for_diluted_eps_chg                                             -0.074240
# bs_c_and_ce_and_sti_detailed_chg                                       0.187873
# bs_other_current_assets_detailed_chg                                   0.021793
# bs_accum_depr_chg                                                     -0.070048
# bs_acct_payable_and_accruals_detailed_chg                             -0.058291
# bs_cur_liab_chg                                                       -0.175381
# cur_ratio_chg                                                          0.298308
# (Close, UEC)                                                          -0.165447
#
#                                            cf_cap_expenditures_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                      0.290332
# cash_flow_to_net_inc.1_lvl                               -0.001027
# cur_ratio_lvl                                             0.045730
# cf_proc_fr_repurch_eqty_detailed_chg                     -0.086086
# cf_cap_expenditures_chg                                   1.000000
# free_cash_flow_per_sh_chg                                 0.338038
# pr_to_free_cash_flow_chg                                  0.084723
# cash_flow_to_net_inc.1_chg                               -0.060685
# is_operating_expn_chg                                    -0.063729
# is_other_operating_expenses_chg                           0.006517
# is_oper_income_chg                                        0.156903
# is_nonop_income_loss_chg                                  0.093894
# is_ni_including_minority_int_ratio_chg                    0.000687
# is_sh_for_diluted_eps_chg                                -0.047230
# bs_c_and_ce_and_sti_detailed_chg                         -0.012650
# bs_other_current_assets_detailed_chg                     -0.098776
# bs_accum_depr_chg                                         0.102573
# bs_acct_payable_and_accruals_detailed_chg                -0.155622
# bs_cur_liab_chg                                          -0.214354
# cur_ratio_chg                                             0.031416
# (Close, UEC)                                              0.048455
#
#                                            free_cash_flow_per_sh_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                        0.114238
# cash_flow_to_net_inc.1_lvl                                 -0.110513
# cur_ratio_lvl                                              -0.069654
# cf_proc_fr_repurch_eqty_detailed_chg                       -0.510161
# cf_cap_expenditures_chg                                     0.338038
# free_cash_flow_per_sh_chg                                   1.000000
# pr_to_free_cash_flow_chg                                   -0.037932
# cash_flow_to_net_inc.1_chg                                 -0.206741
# is_operating_expn_chg                                       0.013682
# is_other_operating_expenses_chg                            -0.010395
# is_oper_income_chg                                          0.651125
# is_nonop_income_loss_chg                                    0.474376
# is_ni_including_minority_int_ratio_chg                      0.062715
# is_sh_for_diluted_eps_chg                                   0.123684
# bs_c_and_ce_and_sti_detailed_chg                           -0.224768
# bs_other_current_assets_detailed_chg                       -0.059655
# bs_accum_depr_chg                                           0.154128
# bs_acct_payable_and_accruals_detailed_chg                  -0.111615
# bs_cur_liab_chg                                            -0.124069
# cur_ratio_chg                                              -0.082153
# (Close, UEC)                                                0.042376
#
#                                            pr_to_free_cash_flow_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                      -0.007700
# cash_flow_to_net_inc.1_lvl                                 0.148775
# cur_ratio_lvl                                              0.025419
# cf_proc_fr_repurch_eqty_detailed_chg                      -0.001518
# cf_cap_expenditures_chg                                    0.084723
# free_cash_flow_per_sh_chg                                 -0.037932
# pr_to_free_cash_flow_chg                                   1.000000
# cash_flow_to_net_inc.1_chg                                -0.110518
# is_operating_expn_chg                                     -0.072536
# is_other_operating_expenses_chg                           -0.049132
# is_oper_income_chg                                        -0.008511
# is_nonop_income_loss_chg                                  -0.155527
# is_ni_including_minority_int_ratio_chg                     0.145165
# is_sh_for_diluted_eps_chg                                  0.019233
# bs_c_and_ce_and_sti_detailed_chg                           0.144054
# bs_other_current_assets_detailed_chg                      -0.682301
# bs_accum_depr_chg                                         -0.019052
# bs_acct_payable_and_accruals_detailed_chg                 -0.419763
# bs_cur_liab_chg                                           -0.400733
# cur_ratio_chg                                              0.124361
# (Close, UEC)                                              -0.133524
#
#                                            cash_flow_to_net_inc.1_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                        -0.033786
# cash_flow_to_net_inc.1_lvl                                   0.792720
# cur_ratio_lvl                                               -0.007846
# cf_proc_fr_repurch_eqty_detailed_chg                         0.005005
# cf_cap_expenditures_chg                                     -0.060685
# free_cash_flow_per_sh_chg                                   -0.206741
# pr_to_free_cash_flow_chg                                    -0.110518
# cash_flow_to_net_inc.1_chg                                   1.000000
# is_operating_expn_chg                                       -0.052938
# is_other_operating_expenses_chg                             -0.027389
# is_oper_income_chg                                          -0.276806
# is_nonop_income_loss_chg                                    -0.202998
# is_ni_including_minority_int_ratio_chg                       0.021716
# is_sh_for_diluted_eps_chg                                    0.411572
# bs_c_and_ce_and_sti_detailed_chg                            -0.086945
# bs_other_current_assets_detailed_chg                        -0.041263
# bs_accum_depr_chg                                           -0.000952
# bs_acct_payable_and_accruals_detailed_chg                   -0.135112
# bs_cur_liab_chg                                              0.034095
# cur_ratio_chg                                                0.073427
# (Close, UEC)                                                 0.059882
#
#                                            is_operating_expn_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                    0.013283
# cash_flow_to_net_inc.1_lvl                              0.020807
# cur_ratio_lvl                                           0.255466
# cf_proc_fr_repurch_eqty_detailed_chg                   -0.040818
# cf_cap_expenditures_chg                                -0.063729
# free_cash_flow_per_sh_chg                               0.013682
# pr_to_free_cash_flow_chg                               -0.072536
# cash_flow_to_net_inc.1_chg                             -0.052938
# is_operating_expn_chg                                   1.000000
# is_other_operating_expenses_chg                         0.642346
# is_oper_income_chg                                     -0.216690
# is_nonop_income_loss_chg                                0.049046
# is_ni_including_minority_int_ratio_chg                 -0.484177
# is_sh_for_diluted_eps_chg                               0.274388
# bs_c_and_ce_and_sti_detailed_chg                       -0.105332
# bs_other_current_assets_detailed_chg                   -0.002780
# bs_accum_depr_chg                                       0.049248
# bs_acct_payable_and_accruals_detailed_chg               0.099616
# bs_cur_liab_chg                                         0.009572
# cur_ratio_chg                                          -0.042026
# (Close, UEC)                                            0.189911
#
#                                            is_other_operating_expenses_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                              0.148730
# cash_flow_to_net_inc.1_lvl                                        0.030846
# cur_ratio_lvl                                                     0.106589
# cf_proc_fr_repurch_eqty_detailed_chg                             -0.066715
# cf_cap_expenditures_chg                                           0.006517
# free_cash_flow_per_sh_chg                                        -0.010395
# pr_to_free_cash_flow_chg                                         -0.049132
# cash_flow_to_net_inc.1_chg                                       -0.027389
# is_operating_expn_chg                                             0.642346
# is_other_operating_expenses_chg                                   1.000000
# is_oper_income_chg                                               -0.150560
# is_nonop_income_loss_chg                                          0.074133
# is_ni_including_minority_int_ratio_chg                           -0.359221
# is_sh_for_diluted_eps_chg                                         0.201391
# bs_c_and_ce_and_sti_detailed_chg                                 -0.067261
# bs_other_current_assets_detailed_chg                              0.022800
# bs_accum_depr_chg                                                 0.240585
# bs_acct_payable_and_accruals_detailed_chg                         0.031970
# bs_cur_liab_chg                                                  -0.006135
# cur_ratio_chg                                                    -0.076668
# (Close, UEC)                                                      0.228284
#
#                                            ...  is_nonop_income_loss_chg  \
# cf_purchase_of_fixed_prod_assets_lvl       ...                 -0.198876
# cash_flow_to_net_inc.1_lvl                 ...                 -0.119277
# cur_ratio_lvl                              ...                 -0.088110
# cf_proc_fr_repurch_eqty_detailed_chg       ...                 -0.118295
# cf_cap_expenditures_chg                    ...                  0.093894
# free_cash_flow_per_sh_chg                  ...                  0.474376
# pr_to_free_cash_flow_chg                   ...                 -0.155527
# cash_flow_to_net_inc.1_chg                 ...                 -0.202998
# is_operating_expn_chg                      ...                  0.049046
# is_other_operating_expenses_chg            ...                  0.074133
# is_oper_income_chg                         ...                  0.520576
# is_nonop_income_loss_chg                   ...                  1.000000
# is_ni_including_minority_int_ratio_chg     ...                 -0.514320
# is_sh_for_diluted_eps_chg                  ...                 -0.014948
# bs_c_and_ce_and_sti_detailed_chg           ...                 -0.341174
# bs_other_current_assets_detailed_chg       ...                 -0.014834
# bs_accum_depr_chg                          ...                  0.178149
# bs_acct_payable_and_accruals_detailed_chg  ...                 -0.166117
# bs_cur_liab_chg                            ...                 -0.218729
# cur_ratio_chg                              ...                  0.012869
# (Close, UEC)                               ...                 -0.191109
#
#                                            is_ni_including_minority_int_ratio_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                                     0.148487
# cash_flow_to_net_inc.1_lvl                                              -0.100861
# cur_ratio_lvl                                                           -0.122602
# cf_proc_fr_repurch_eqty_detailed_chg                                    -0.228474
# cf_cap_expenditures_chg                                                  0.000687
# free_cash_flow_per_sh_chg                                                0.062715
# pr_to_free_cash_flow_chg                                                 0.145165
# cash_flow_to_net_inc.1_chg                                               0.021716
# is_operating_expn_chg                                                   -0.484177
# is_other_operating_expenses_chg                                         -0.359221
# is_oper_income_chg                                                       0.334374
# is_nonop_income_loss_chg                                                -0.514320
# is_ni_including_minority_int_ratio_chg                                   1.000000
# is_sh_for_diluted_eps_chg                                                0.100554
# bs_c_and_ce_and_sti_detailed_chg                                         0.026551
# bs_other_current_assets_detailed_chg                                     0.139902
# bs_accum_depr_chg                                                       -0.087148
# bs_acct_payable_and_accruals_detailed_chg                                0.107132
# bs_cur_liab_chg                                                          0.178511
# cur_ratio_chg                                                           -0.007390
# (Close, UEC)                                                            -0.035040
#
#                                            is_sh_for_diluted_eps_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                        0.062312
# cash_flow_to_net_inc.1_lvl                                  0.401535
# cur_ratio_lvl                                               0.030149
# cf_proc_fr_repurch_eqty_detailed_chg                       -0.074240
# cf_cap_expenditures_chg                                    -0.047230
# free_cash_flow_per_sh_chg                                   0.123684
# pr_to_free_cash_flow_chg                                    0.019233
# cash_flow_to_net_inc.1_chg                                  0.411572
# is_operating_expn_chg                                       0.274388
# is_other_operating_expenses_chg                             0.201391
# is_oper_income_chg                                          0.090860
# is_nonop_income_loss_chg                                   -0.014948
# is_ni_including_minority_int_ratio_chg                      0.100554
# is_sh_for_diluted_eps_chg                                   1.000000
# bs_c_and_ce_and_sti_detailed_chg                           -0.100197
# bs_other_current_assets_detailed_chg                        0.122306
# bs_accum_depr_chg                                          -0.022700
# bs_acct_payable_and_accruals_detailed_chg                  -0.069413
# bs_cur_liab_chg                                            -0.100799
# cur_ratio_chg                                               0.061610
# (Close, UEC)                                               -0.034989
#
#                                            bs_c_and_ce_and_sti_detailed_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                               0.027570
# cash_flow_to_net_inc.1_lvl                                        -0.044781
# cur_ratio_lvl                                                      0.042514
# cf_proc_fr_repurch_eqty_detailed_chg                               0.187873
# cf_cap_expenditures_chg                                           -0.012650
# free_cash_flow_per_sh_chg                                         -0.224768
# pr_to_free_cash_flow_chg                                           0.144054
# cash_flow_to_net_inc.1_chg                                        -0.086945
# is_operating_expn_chg                                             -0.105332
# is_other_operating_expenses_chg                                   -0.067261
# is_oper_income_chg                                                -0.395281
# is_nonop_income_loss_chg                                          -0.341174
# is_ni_including_minority_int_ratio_chg                             0.026551
# is_sh_for_diluted_eps_chg                                         -0.100197
# bs_c_and_ce_and_sti_detailed_chg                                   1.000000
# bs_other_current_assets_detailed_chg                              -0.094750
# bs_accum_depr_chg                                                 -0.178190
# bs_acct_payable_and_accruals_detailed_chg                          0.010624
# bs_cur_liab_chg                                                    0.022851
# cur_ratio_chg                                                      0.296606
# (Close, UEC)                                                       0.066612
#
#                                            bs_other_current_assets_detailed_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                                   0.007508
# cash_flow_to_net_inc.1_lvl                                            -0.362538
# cur_ratio_lvl                                                          0.000504
# cf_proc_fr_repurch_eqty_detailed_chg                                   0.021793
# cf_cap_expenditures_chg                                               -0.098776
# free_cash_flow_per_sh_chg                                             -0.059655
# pr_to_free_cash_flow_chg                                              -0.682301
# cash_flow_to_net_inc.1_chg                                            -0.041263
# is_operating_expn_chg                                                 -0.002780
# is_other_operating_expenses_chg                                        0.022800
# is_oper_income_chg                                                     0.086171
# is_nonop_income_loss_chg                                              -0.014834
# is_ni_including_minority_int_ratio_chg                                 0.139902
# is_sh_for_diluted_eps_chg                                              0.122306
# bs_c_and_ce_and_sti_detailed_chg                                      -0.094750
# bs_other_current_assets_detailed_chg                                   1.000000
# bs_accum_depr_chg                                                     -0.001403
# bs_acct_payable_and_accruals_detailed_chg                              0.369355
# bs_cur_liab_chg                                                        0.351133
# cur_ratio_chg                                                         -0.017416
# (Close, UEC)                                                          -0.017956
#
#                                            bs_accum_depr_chg  \
# cf_purchase_of_fixed_prod_assets_lvl               -0.217791
# cash_flow_to_net_inc.1_lvl                         -0.000664
# cur_ratio_lvl                                      -0.168532
# cf_proc_fr_repurch_eqty_detailed_chg               -0.070048
# cf_cap_expenditures_chg                             0.102573
# free_cash_flow_per_sh_chg                           0.154128
# pr_to_free_cash_flow_chg                           -0.019052
# cash_flow_to_net_inc.1_chg                         -0.000952
# is_operating_expn_chg                               0.049248
# is_other_operating_expenses_chg                     0.240585
# is_oper_income_chg                                  0.090743
# is_nonop_income_loss_chg                            0.178149
# is_ni_including_minority_int_ratio_chg             -0.087148
# is_sh_for_diluted_eps_chg                          -0.022700
# bs_c_and_ce_and_sti_detailed_chg                   -0.178190
# bs_other_current_assets_detailed_chg               -0.001403
# bs_accum_depr_chg                                   1.000000
# bs_acct_payable_and_accruals_detailed_chg          -0.024549
# bs_cur_liab_chg                                    -0.003110
# cur_ratio_chg                                      -0.072872
# (Close, UEC)                                       -0.128456
#
#                                            bs_acct_payable_and_accruals_detailed_chg  \
# cf_purchase_of_fixed_prod_assets_lvl                                       -0.039902
# cash_flow_to_net_inc.1_lvl                                                 -0.229581
# cur_ratio_lvl                                                              -0.101035
# cf_proc_fr_repurch_eqty_detailed_chg                                       -0.058291
# cf_cap_expenditures_chg                                                    -0.155622
# free_cash_flow_per_sh_chg                                                  -0.111615
# pr_to_free_cash_flow_chg                                                   -0.419763
# cash_flow_to_net_inc.1_chg                                                 -0.135112
# is_operating_expn_chg                                                       0.099616
# is_other_operating_expenses_chg                                             0.031970
# is_oper_income_chg                                                         -0.172025
# is_nonop_income_loss_chg                                                   -0.166117
# is_ni_including_minority_int_ratio_chg                                      0.107132
# is_sh_for_diluted_eps_chg                                                  -0.069413
# bs_c_and_ce_and_sti_detailed_chg                                            0.010624
# bs_other_current_assets_detailed_chg                                        0.369355
# bs_accum_depr_chg                                                          -0.024549
# bs_acct_payable_and_accruals_detailed_chg                                   1.000000
# bs_cur_liab_chg                                                             0.652137
# cur_ratio_chg                                                              -0.273661
# (Close, UEC)                                                                0.214043
#
#                                            bs_cur_liab_chg  cur_ratio_chg  \
# cf_purchase_of_fixed_prod_assets_lvl              0.013318       0.056319
# cash_flow_to_net_inc.1_lvl                       -0.207259       0.126610
# cur_ratio_lvl                                    -0.277044       0.456486
# cf_proc_fr_repurch_eqty_detailed_chg             -0.175381       0.298308
# cf_cap_expenditures_chg                          -0.214354       0.031416
# free_cash_flow_per_sh_chg                        -0.124069      -0.082153
# pr_to_free_cash_flow_chg                         -0.400733       0.124361
# cash_flow_to_net_inc.1_chg                        0.034095       0.073427
# is_operating_expn_chg                             0.009572      -0.042026
# is_other_operating_expenses_chg                  -0.006135      -0.076668
# is_oper_income_chg                               -0.133754      -0.052274
# is_nonop_income_loss_chg                         -0.218729       0.012869
# is_ni_including_minority_int_ratio_chg            0.178511      -0.007390
# is_sh_for_diluted_eps_chg                        -0.100799       0.061610
# bs_c_and_ce_and_sti_detailed_chg                  0.022851       0.296606
# bs_other_current_assets_detailed_chg              0.351133      -0.017416
# bs_accum_depr_chg                                -0.003110      -0.072872
# bs_acct_payable_and_accruals_detailed_chg         0.652137      -0.273661
# bs_cur_liab_chg                                   1.000000      -0.408056
# cur_ratio_chg                                    -0.408056       1.000000
# (Close, UEC)                                      0.224652      -0.236677
#
#                                            (Close, UEC)
# cf_purchase_of_fixed_prod_assets_lvl           0.165096
# cash_flow_to_net_inc.1_lvl                     0.040760
# cur_ratio_lvl                                 -0.114813
# cf_proc_fr_repurch_eqty_detailed_chg          -0.165447
# cf_cap_expenditures_chg                        0.048455
# free_cash_flow_per_sh_chg                      0.042376
# pr_to_free_cash_flow_chg                      -0.133524
# cash_flow_to_net_inc.1_chg                     0.059882
# is_operating_expn_chg                          0.189911
# is_other_operating_expenses_chg                0.228284
# is_oper_income_chg                            -0.147628
# is_nonop_income_loss_chg                      -0.191109
# is_ni_including_minority_int_ratio_chg        -0.035040
# is_sh_for_diluted_eps_chg                     -0.034989
# bs_c_and_ce_and_sti_detailed_chg               0.066612
# bs_other_current_assets_detailed_chg          -0.017956
# bs_accum_depr_chg                             -0.128456
# bs_acct_payable_and_accruals_detailed_chg      0.214043
# bs_cur_liab_chg                                0.224652
# cur_ratio_chg                                 -0.236677
# (Close, UEC)                                   1.000000
#
# [21 rows x 21 columns]

# %%
def enhanced_feature_selector(
    X, 
    Y,
    min_corr=0.15,  # Lower initial threshold
    model_type='lasso', 
    n_features=20
):
    """
    Improved feature selection that:
    1. Pre-filters with correlation
    2. Uses model-based selection
    3. Validates with cross-validation
    """
    # 1. Initial correlation filter (broader net)
    target_col = Y.columns
    data = pd.concat([X,Y],axis = 1)
    corr = data.corr()[target_col].abs()
    #print(corr)
    candidates = corr[corr > min_corr].index.tolist()
    candidates.remove(target_col)
    
    if not candidates:
        raise ValueError("No features meet initial correlation threshold")
    
    X = data[candidates]
    y = data[target_col]
    
    # 2. Model-based selection
    if model_type == 'lasso':
        model = LassoCV(cv=5, max_iter=10)
    else:
        model = RidgeCV(cv=5)
    
    # 3. Recursive Feature Elimination
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('rfe', RFE(estimator=model, n_features_to_select=n_features))
    ])
    
    pipeline.fit(X, y)
    selected_features = X.columns[pipeline.named_steps['rfe'].support_].tolist()
    
    return selected_features

# %% [markdown]
# ## Check correlations

# %%
lvl = fdmnt.columns
chg = fdmnt.columns
fdmt = clean_feature(fdmnt,chg,lvl,standardize=False)
merged = pd.concat([df,fdmt],axis = 1).fillna(0)
correlations = merged.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 lvl = fdmnt.columns
#       2 chg = fdmnt.columns
# ----> 3 fdmt = clean_feature(fdmnt,chg,lvl,standardize=False)
#       4 merged = pd.concat([df,fdmt],axis = 1).fillna(0)
#       5 correlations = merged.corr()
#
# NameError: name 'clean_feature' is not defined

# %%
correlations.iloc[0].sort_values(ascending=False).dropna().head(50)
# Out:
# (Close, BABA)                              1.000000
# bs_gross_fix_asset_chg                     0.313473
# ebitda_margin.2_chg                        0.267233
# ebitda_margin.1_chg                        0.267233
# ebitda_margin_chg                          0.267233
# oper_margin_chg                            0.257848
# net_debt_chg                               0.256577
# bs_disclosed_intangibles_chg               0.255555
# bs_goodwill_chg                            0.252878
# market_cap_chg                             0.235327
# ebita_chg                                  0.233704
# ebitda_chg                                 0.232746
# ebitda.2_chg                               0.232746
# ebitda.1_chg                               0.232746
# ebit_chg                                   0.230266
# is_oper_income_chg                         0.230266
# net_debt_lvl                               0.228293
# ebitda_per_sh_chg                          0.225421
# oper_margin_lvl                            0.222148
# gross_margin_lvl                           0.217962
# ebitda_margin.1_lvl                        0.216799
# ebitda_margin.2_lvl                        0.216799
# ebitda_margin_lvl                          0.216799
# bs_lt_borrow_chg                           0.214933
# cf_cash_from_inv_act_lvl                   0.210778
# profit_margin.1_lvl                        0.210370
# profit_margin_lvl                          0.210370
# bs_st_borrow_chg                           0.209178
# cf_other_investing_act_detailed_lvl        0.205540
# bs_accts_rec_excl_notes_rec_lvl            0.178073
# net_debt_to_shrhldr_eqty_chg               0.174395
# bs_net_fix_asset_lvl                       0.173233
# bs_other_intangible_assets_detailed_chg    0.173050
# bs_short_term_debt_detailed_chg            0.172805
# bs_inventories_lvl                         0.172325
# bs_other_inv_lvl                           0.172325
# tot_debt_to_tot_eqy_chg                    0.171949
# bs_net_fix_asset_chg                       0.170417
# free_cash_flow_equity_chg                  0.167128
# bs_other_ins_res_to_shrhldr_eqy_lvl        0.160345
# bs_gross_fix_asset_lvl                     0.158592
# bs_lt_capital_lease_obligations_lvl        0.155016
# bs_total_capital_leases_lvl                0.152075
# is_ni_including_minority_int_ratio_chg     0.150742
# cf_cash_from_oper_chg                      0.150267
# cf_free_cash_flow_chg                      0.150062
# cash_flow_per_sh_chg                       0.148719
# free_cash_flow_per_sh_chg                  0.148482
# bs_long_term_borrowings_detailed_chg       0.147734
# bs_other_current_liabs_detailed_lvl        0.144275
# Name: (Close, BABA), dtype: float64

# %%
correlations.iloc[0].sort_values(ascending=True).dropna().head(50)
# Out:
# bs_other_noncurrent_liabs_detailed_lvl      -0.389199
# bs_other_noncurrent_assets_detailed_lvl     -0.359893
# bs_other_current_receivable_lvl             -0.357763
# bs_acct_note_rcv_lvl                        -0.350080
# bs_other_noncur_liabs_sub_detailed_lvl      -0.329768
# bs_acct_payable_and_accruals_detailed_lvl   -0.320016
# bs_st_deferred_revenue_chg                  -0.302559
# bs_other_assets_def_chrg_other_lvl          -0.301163
# is_cog_and_services_sold_chg                -0.298872
# is_cogs_chg                                 -0.298872
# bs_st_deferred_revenue_lvl                  -0.296715
# is_sg_and_a_expense_chg                     -0.287526
# bs_cur_asset_report_lvl                     -0.286522
# bs_c_and_ce_and_sti_detailed_lvl            -0.283061
# bs_cur_liab_lvl                             -0.277897
# is_sg_and_a_expense_lvl                     -0.277368
# is_operating_expn_lvl                       -0.270665
# bs_sh_cap_and_apic_chg                      -0.266515
# bs_add_paid_in_cap_chg                      -0.266515
# bs_pure_retained_earnings_lvl               -0.263923
# revenue_per_sh_chg                          -0.261888
# bs_acct_payable_chg                         -0.261640
# bs_add_paid_in_cap_lvl                      -0.261427
# bs_sh_cap_and_apic_lvl                      -0.261427
# bs_eqty_bef_minority_int_detailed_lvl       -0.261369
# bs_tot_liab_lvl                             -0.260638
# bs_accrued_liabilities_lvl                  -0.260013
# bs_cash_near_cash_item_lvl                  -0.259939
# bs_amt_of_tsy_stock_chg                     -0.258429
# bs_tot_liab_and_eqy_lvl                     -0.258425
# bs_tot_asset_lvl                            -0.258425
# free_cash_flow_equity_lvl                   -0.255501
# bs_total_equity_lvl                         -0.255439
# is_cogs_lvl                                 -0.255017
# is_cog_and_services_sold_lvl                -0.255017
# is_sales_revenue_turnover_lvl               -0.253582
# is_sales_and_services_revenues_lvl          -0.253582
# cf_free_cash_flow_firm_lvl                  -0.252860
# is_operating_expenses_r_and_d_lvl           -0.251254
# revenue_per_sh_lvl                          -0.248661
# is_gross_profit.1_lvl                       -0.248362
# is_gross_profit_lvl                         -0.248362
# cf_cash_from_oper_lvl                       -0.240632
# cf_free_cash_flow_lvl                       -0.240436
# cash_flow_per_sh_lvl                        -0.236125
# free_cash_flow_per_sh_lvl                   -0.235890
# bs_lt_invest_lvl                            -0.234931
# bs_long_term_investments_lvl                -0.234931
# bs_tot_non_cur_asset_lvl                    -0.234728
# cf_non_cash_items_detailed_lvl              -0.228462
# Name: (Close, BABA), dtype: float64

# %% [markdown]
# ## Regime Identification

# %%
fred_data = pd.read_csv('fred_data.csv',index_col=0,parse_dates=True)
predictors = fred_data[fred_data['Name'].isin(['OECD US Leading Indicator','US Consumer Prices'])]
predictors = pd.pivot_table(predictors, index='Date', columns='Name', values='value')
predictors = predictors.ffill()

# %%
predictors['Growth_US'] =predictors['OECD US Leading Indicator'].pct_change(12)
predictors['Inflation_US'] = predictors['US Consumer Prices'].pct_change(12)
df = predictors.copy()

# %%
conditions = [
    (df['Growth_US'] > -0.03) & (df['Growth_US'] <= 0) & (df['Inflation_US'] > 0),    # Stagflation
    ((df['Growth_US'] > 0)) & (df['Inflation_US'] > 0) & (df['Inflation_US'] <0.03),   # Steady State
    (df['Growth_US'] > -0.03) & (df['Growth_US'] <= 0) & (df['Inflation_US'] <= 0),  # Cautious
    (df['Growth_US'] > 0) & (df['Inflation_US'] <= 0),                              # Goldilocks
    (df['Growth_US'] > 0) & (df['Inflation_US'] >= 0.03),                              #Inflation
    (df['Growth_US'] <= -0.03)                                                         #Crisis
]
#labels = ['Stagflation', 'Steady State', "Cautious", "Goldilocks", "Inflation", "Crisis"]
labels = [-1,2,0,3,1,-2]
df['Regime'] = np.select(conditions, labels, default=np.nan)
df = df.dropna()

# %%
df['Regime'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import yfinance as yf

# %%
tkrs = ['USO', 'SPY', 'TLT', 'GLD','^VIX',"SPHY",'XLF', 'XLY', 'XLI', 'XLB', 'XLI', 'XLP', 'XLV', 'XBI']
prices = yf.download(tkrs, start='2010-01-01')[['Close']]
prices = prices.ffill().dropna()
prices.columns = prices.columns.get_level_values(1).unique()
corrdata = prices[['XLY', 'XLI', 'XLB', 'XLI', 'XLP', 'XLV', 'XBI']].pct_change().fillna(0)#.rolling(40).apply(get_x_asset_corr))
corrdata = corrdata.rolling(10).corr()
prices['cross_asset_corr'] = corrdata.groupby(corrdata.index.get_level_values(0)).mean().mean(axis =1)-1/(corrdata.shape[1])#.mean().plot()
#prices = prices.reindex(index =pd.date_range(start='2010-01-01',end= datetime.datetime.now().strftime('%Y-%m-%d'))).shift()
#prices.ffill( inplace=True)
#prices =prices.reindex(df.index)
prices[['GLD',"USO","SPHY","TLT","^VIX","SPY"]] = prices[['GLD',"USO","SPHY","TLT","^VIX","SPY"]].pct_change().fillna(0)
prices = prices[['GLD',"USO","SPHY","TLT","^VIX",'cross_asset_corr',"SPY"]]
prices['credit_spr'] = prices['TLT'] - prices['SPHY']
prices = prices[['GLD',"USO","TLT","^VIX",'cross_asset_corr',"SPY",'credit_spr']].shift().dropna()
# Out:
# [*********************100%***********************]  13 of 13 completed

# %% [markdown]
# regimes = [0]
# for i in range(1,len(prices)):
#     try:
#         model = GaussianMixture(n_components=4, random_state=42)
#         model.fit(prices.iloc[:i])
#         label = model.predict(prices.iloc[[i]])
#     except:
#         label = [np.nan]
#     regimes.append(label[0])
#     #print(label)

# %%
model = GaussianMixture(n_components=4, random_state=42)
model = KMeans(n_clusters =3, random_state=42)
model.fit(prices.iloc[:2000])
labels = model.predict(prices)
prices['regime'] = labels

# %%
regime_vis = prices[['SPY','regime']]

# %%
regime_vis['SPY'] = (1+regime_vis['SPY']).cumprod()-1
# Out:
# C:\Users\kmavy\AppData\Local\Temp\ipykernel_27148\4207767365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regime_vis['SPY'] = (1+regime_vis['SPY']).cumprod()-1

# %%
import seaborn as sns
plt.figure(figsize=(10, 5))
colors = ['#747FE3', '#8EE35D', '#E37346','goldenrod']
sns.scatterplot(data = regime_vis,x = regime_vis.index,y = regime_vis['SPY'],hue = 'regime',palette = colors,s = 10)\
.set_title('SPY Returns Clustered by Regime')
# Out:
# C:\Users\kmavy\AppData\Local\Temp\ipykernel_27148\1671232744.py:4: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
#   sns.scatterplot(data = regime_vis,x = regime_vis.index,y = regime_vis['SPY'],hue = 'regime',palette = colors,s = 10)\
# Text(0.5, 1.0, 'SPY Returns Clustered by Regime')

# %%
regime_vis.tail(60)
# Out:
# Ticker           SPY  regime
# Date
# 2025-05-14  4.420949       2
# 2025-05-15  4.427878       2
# 2025-05-16  4.454389       2
# 2025-05-19  4.488937       2
# 2025-05-20  4.494941       2
# 2025-05-21  4.476467       2
# 2025-05-22  4.384184       2
# 2025-05-23  4.386309       2
# 2025-05-27  4.349543       2
# 2025-05-28  4.460763       2
# 2025-05-29  4.429170       0
# 2025-05-30  4.450602       0
# 2025-06-02  4.444505       0
# 2025-06-03  4.475173       2
# 2025-06-04  4.506396       2
# 2025-06-05  4.504918       2
# 2025-06-06  4.478314       2
# 2025-06-09  4.534571       2
# 2025-06-10  4.539559       2
# 2025-06-11  4.570966       1
# 2025-06-12  4.555078       1
# 2025-06-13  4.577156       3
# 2025-06-16  4.514802       1
# 2025-06-17  4.567272       1
# 2025-06-18  4.519699       2
# 2025-06-20  4.518867       2
# 2025-06-23  4.505906       2
# 2025-06-24  4.560290       2
# 2025-06-25  4.621716       2
# 2025-06-26  4.624866       2
# 2025-06-27  4.668874       2
# 2025-06-30  4.697039       2
# 2025-07-01  4.724277       2
# 2025-07-02  4.722425       2
# 2025-07-03  4.748366       1
# 2025-07-07  4.793671       1
# 2025-07-08  4.750497       1
# 2025-07-09  4.747347       1
# 2025-07-10  4.781812       1
# 2025-07-11  4.798118       3
# 2025-07-14  4.777735       1
# 2025-07-15  4.788761       1
# 2025-07-16  4.764024       2
# 2025-07-17  4.783294       2
# 2025-07-18  4.818686       2
# 2025-07-21  4.814424       2
# 2025-07-22  4.825450       1
# 2025-07-23  4.826283       2
# 2025-07-24  4.875850       2
# 2025-07-25  4.877796       2
# 2025-07-28  4.902625       2
# 2025-07-29  4.901143       2
# 2025-07-30  4.885578       1
# 2025-07-31  4.878167       1
# 2025-08-01  4.856116       1
# 2025-08-04  4.760132       1
# 2025-08-05  4.847685       2
# 2025-08-06  4.818037       1
# 2025-08-07  4.862602       1
# 2025-08-08  4.857691       1

# %%
# pip install scikit-learn numpy pandas
import numpy as np, pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler

# %%
for i in range(2,7):
    model = GaussianMixture(n_components=i, random_state=42)
    model.fit(prices)
    labels = model.predict(prices)
    score = silhouette_score(prices, labels)
    print(i, score)
# Out:
# 2 0.14361687277036997
# 3 0.11571375060505047
# 4 0.18914682107670913
# 5 -0.04826379985553877
# 6 0.014316637378098023
