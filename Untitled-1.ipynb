# %%
import requests
import pandas as pd
import numpy as np
import os

from functools import reduce

from saber import DataMgmt as dmgmt
from saber import fundEQ_lib as f_eq

# %%
dm = dmgmt.DataLake()
cn_eq_tkrs = ['1398.HK',"0939.HK","1288.HK","0857.HK","0386.HK","1088.HK","600519.SS","0941.HK","TCEHY","9988.HK","1211.HK","300750.SZ"]
us_eq_tkrs = ['AAPL','MSFT',"JPM","GOOG","NVDA","GS","XOM","CVX","JNJ","UNH","V","WMT","CAT","AMD","AMZN"]
in_eq_tkrs = ["RELIANCE.NS","TCS.NS","INFY.NS","HDFCBANK.NS","SBIN.NS","LT.NS","ULTRACEMCO.NS","NTPC.NS", "BHARTIARTL.NS","ITC.NS","HINDUNILVR.NS", "MARUTI.NS", "TATAMOTORS.NS","SUNPHARMA.NS", "ADANIPORTS.NS"]
kr_eq_tkrs = ["005930.KS","000660.KS",  "373220.KS","010950.KS", "051910.KS", "005380.KS",  "000270.KS", "005490.KS",  "035420.KS", "035720.KS", "329180.KS", "010140.KS",  "105560.KS",  "055550.KS", "207940.KS"]
eu_eq_tkrs = ["ASML.AS","SAP.DE", "TTE.PA","SIE.DE", "ALV.DE",  "BNP.PA",  "AIR.PA", "SAN.PA", "VOW3.DE", "ABI.BR", "IBE.MC","SAN.MC",  "ENI.MI",    "ISP.MI","SHEL.L" ]
uranium_producers = [
    "CCJ",      # Cameco
    "KAP.L",    # Kazatomprom (London)
    "UEC",      # Uranium Energy Corp
    "UUUU",     # Energy Fuels
    "URG",      # Ur-Energy
    "EU",       # enCore Energy
    "PDN.AX",   # Paladin Energy
    "BOE.AX",   # Boss Energy
    "PEN.AX",   # Peninsula Energy
    "LOT.AX",   # Lotus Resources
    "BMN.AX",   # Bannerman Energy
    "DYL.AX",   # Deep Yellow
    "GLO.TO",   # Global Atomic
]
r2k_map = pd.read_csv('russell2000map.csv')
r2k_tkrs = r2k_map['ticker'].tolist()
r2k_util_tkrs = r2k_map[r2k_map['sector'] == 'Utilities']['ticker'].tolist()

# %%
uranium_eq = f_eq.get_multi_equity_fundamental_data(uranium_producers,start_dt = "2000-01-01",statement = 'all')
dm.save_data('raw','fundamental','equities',uranium_eq,'uranium_producers_full_acc_data.csv',['date','ticker'])

# %%
cn_eq = f_eq.get_multi_equity_fundamental_data(cn_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
dm.save_data('raw','fundamental','equities',cn_eq,'cn_full_acc_data.csv',['date','ticker'])
# Out:
# c:\Users\kmavy\anaconda3\lib\site-packages\saber\DataMgmt.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(path,index_col=index_col,parse_dates=True)
# c:\Users\kmavy\anaconda3\lib\site-packages\saber\DataMgmt.py:46: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   saved[col] = saved[col].combine_first(new_df[col])

# %%
cn_eq = f_eq.get_multi_equity_fundamental_data(cn_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
dm.save_data('raw','fundamental','equities',cn_eq,'cn_full_acc_data.csv',['date','ticker'])
us_eq = f_eq.get_multi_equity_fundamental_data(us_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
dm.save_data('raw','fundamental','equities',us_eq,'us_full_acc_data.csv',['date','ticker'])
in_eq = f_eq.get_multi_equity_fundamental_data(in_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
dm.save_data('raw','fundamental','equities',in_eq,'in_full_acc_data.csv',['date','ticker'])
kr_eq = f_eq.get_multi_equity_fundamental_data(kr_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
eu_eq = f_eq.get_multi_equity_fundamental_data(eu_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
dm.save_data('raw','fundamental','equities',kr_eq,'kr_full_acc_data.csv',['date','ticker'])
dm.save_data('raw','fundamental','equities',eu_eq,'eu_full_acc_data.csv',['date','ticker'])
r2k_eq = f_eq.get_multi_equity_fundamental_data(r2k_tkrs,start_dt = "2000-01-01",statement = 'all')
r2k_util_tkrs = f_eq.get_multi_equity_fundamental_data(r2k_util_tkrs,start_dt = "2000-01-01",statement = 'all')
dm.save_data('raw','fundamental','equities',r2k_eq,'r2k_full_acc_data.csv',['date','ticker'])
dm.save_data('raw','fundamental','equities',r2k_util_tkrs,'r2k_utils_full_acc_data.csv',['date','ticker'])
# Out:
# c:\Users\kmavy\anaconda3\lib\site-packages\saber\DataMgmt.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(path,index_col=index_col,parse_dates=True)
# c:\Users\kmavy\anaconda3\lib\site-packages\saber\DataMgmt.py:46: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   saved[col] = saved[col].combine_first(new_df[col])
# c:\Users\kmavy\anaconda3\lib\site-packages\saber\DataMgmt.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
regions = [
    (cn_eq_tkrs, 'cn_full_acc_data.csv'),
    (us_eq_tkrs, 'us_full_acc_data.csv'),
    (in_eq_tkrs, 'in_full_acc_data.csv'),
    (kr_eq_tkrs, 'kr_full_acc_data.csv'),
    (eu_eq_tkrs, 'eu_full_acc_data.csv'),
    (r2k_tkrs, 'r2k_full_acc_data.csv'),
    (r2k_util_tkrs, 'r2k_utils_full_acc_data.csv'),
]

for tkrs, filename in regions:
    eq = f_eq.get_multi_equity_fundamental_data(tkrs, start_dt="2000-01-01", statement='all')
    dm.save_data('raw', 'fundamental', 'equities', eq, filename, ['date', 'ticker'])
    print(f"Saved {filename}")
# Out:
# c:\Users\kmavy\anaconda3\lib\site-packages\saber\DataMgmt.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(path,index_col=index_col,parse_dates=True)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[5], line 13
#      11 for tkrs, filename in regions:
#      12     eq = f_eq.get_multi_equity_fundamental_data(tkrs, start_dt="2000-01-01", statement='all')
# ---> 13     dm.save_data('raw', 'fundamental', 'equities', eq, filename, ['date', 'ticker'])
#      14     print(f"Saved {filename}")
#
# File c:\Users\kmavy\anaconda3\lib\site-packages\saber\DataMgmt.py:67, in DataLake.save_data(self, dataclass, dataype, asset_class, df, filename, index_col)
# ...

# %%
dm = dmgmt.DataLake()
cn_eq_tkrs = ['1398.HK',"0939.HK","1288.HK","0857.HK","0386.HK","1088.HK","600519.SS","0941.HK","TCEHY","9988.HK","1211.HK","300750.SZ"]
us_eq_tkrs = ['AAPL','MSFT',"JPM","GOOG","NVDA","GS","XOM","CVX","JNJ","UNH","V","WMT","CAT","AMD","AMZN"]
in_eq_tkrs = ["RELIANCE.NS","TCS.NS","INFY.NS","HDFCBANK.NS","SBIN.NS","LT.NS","ULTRACEMCO.NS","NTPC.NS", "BHARTIARTL.NS","ITC.NS","HINDUNILVR.NS", "MARUTI.NS", "TATAMOTORS.NS","SUNPHARMA.NS", "ADANIPORTS.NS"]
kr_eq_tkrs = ["005930.KS","000660.KS",  "373220.KS","010950.KS", "051910.KS", "005380.KS",  "000270.KS", "005490.KS",  "035420.KS", "035720.KS", "329180.KS", "010140.KS",  "105560.KS",  "055550.KS", "207940.KS"]
eu_eq_tkrs = ["ASML.AS","SAP.DE", "TTE.PA","SIE.DE", "ALV.DE",  "BNP.PA",  "AIR.PA", "SAN.PA", "VOW3.DE", "ABI.BR", "IBE.MC","SAN.MC",  "ENI.MI",    "ISP.MI","SHEL.L" ]

cn_eq = get_multi_equity_fundamental_data(cn_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
us_eq = get_multi_equity_fundamental_data(us_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
in_eq = get_multi_equity_fundamental_data(in_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
kr_eq = get_multi_equity_fundamental_data(kr_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
eu_eq = get_multi_equity_fundamental_data(eu_eq_tkrs,start_dt = "2000-01-01",statement = 'all')
r2k_eq = get_multi_equity_fundamental_data(russell2000_tickers,start_dt = "2000-01-01",statement = 'all')

cn_eq = cn_eq.reset_index().set_index(['date','ticker'])
us_eq = us_eq.reset_index().set_index(['date','ticker'])
in_eq = in_eq.reset_index().set_index(['date','ticker'])
kr_eq = kr_eq.reset_index().set_index(['date','ticker'])
eu_eq = eu_eq.reset_index().set_index(['date','ticker'])
r2k_eq = r2k_eq.reset_index().set_index(['date','ticker'])

cn_eq_old = dm.read_data('raw','fundamental','equities','cn_full_acc_data.csv',['date','ticker'])
us_eq_old = dm.read_data('raw','fundamental','equities','us_full_acc_data.csv',['date','ticker'])
in_eq_old = dm.read_data('raw','fundamental','equities','in_full_acc_data.csv',['date','ticker'])
kr_eq_old = dm.read_data('raw','fundamental','equities','kr_full_acc_data.csv',['date','ticker'])
eu_eq_old = dm.read_data('raw','fundamental','equities','eu_full_acc_data.csv',['date','ticker'])



dm.save_data('raw','fundamental','equities',cn_eq,'cn_full_acc_data.csv',['date','ticker'])
dm.save_data('raw','fundamental','equities',us_eq,'us_full_acc_data.csv',['date','ticker'])
dm.save_data('raw','fundamental','equities',in_eq,'in_full_acc_data.csv',['date','ticker'])
dm.save_data('raw','fundamental','equities',kr_eq,'kr_full_acc_data.csv',['date','ticker'])
dm.save_data('raw','fundamental','equities',eu_eq,'eu_full_acc_data.csv',['date','ticker'])
dm.save_data('raw','fundamental','equities',r2k_eq,'r2k_full_acc_data.csv',['date','ticker'])
# Out:
# C:\Users\kmavy\AppData\Local\Temp\ipykernel_23692\958951713.py:37: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   full_df = full_df.groupby('ticker', group_keys=False).apply(lambda g: g.ffill())
# C:\Users\kmavy\AppData\Local\Temp\ipykernel_23692\958951713.py:37: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   full_df = full_df.groupby('ticker', group_keys=False).apply(lambda g: g.ffill())
# ...

# %%
import pandas as pd

# Get full Russell 2000 proxy via IWM holdings
url = "https://www.ishares.com/us/products/239710/ishares-russell-2000-etf/1467271812596.ajax?fileType=csv&fileName=IWM_holdings&dataType=fund"
holdings = pd.read_csv(url, skiprows=9)

tickers = holdings['Ticker'].dropna().unique().tolist()

print("Total tickers:", len(tickers))
# Out:
# Total tickers: 1942

# %%
import pandas as pd
import yfinance as yf
rows = []
for t in tickers:
    try:
        info = yf.Ticker(t).info
        rows.append({
            "ticker": t,
            "name": info.get("longName") or info.get("shortName"),
            "sector": info.get("sector"),
            "industry": info.get("industry"),
        })
        print("ok")
    except Exception:
        rows.append({"ticker": t, "name": None, "sector": None, "industry": None})

df = pd.DataFrame(rows, columns=["ticker","name","sector","industry"])
df.to_csv("russell2000map.csv", index=False)
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ...
